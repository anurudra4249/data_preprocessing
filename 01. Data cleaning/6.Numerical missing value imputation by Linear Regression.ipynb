# %% [markdown]
# # data cleaning by linear regression

# %% [markdown]
# ### Step 1: Separate the NULL values from the dataframe (df) and consider as test data
# ### Step 2: Drop the NULL values from the data frame (df) and consider as train data
# ### Step 3: Create the X_train & y_train from train data
# ### Step 4: Build the Linear Regression Model
# ### Step 5: Create the x_test from the test _data
# ### Step 6: Apply the model on x_test of test data and make predictions
# ### Step 7: Replace the missing values with predicted values

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/singh/OneDrive/Desktop/Train.csv")

# %%
df.sample(8)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 940    941          90       RL         55.0    12640   Pave   NaN      IR1
# 613    614          20       RL         70.0     8402   Pave   NaN      Reg
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1235  1236          70       RL         96.0    13132   Pave   NaN      Reg
# 680    681         120       RL         50.0     8012   Pave   NaN      Reg
# 1416  1417         190       RM         60.0    11340   Pave   NaN      Reg
# 1286  1287          20       RL          NaN     9790   Pave   NaN      Reg
# 1418  1419          20       RL         71.0     9204   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 940          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 613          Lvl    AllPub    Inside       Gtl      Mitchel      Feedr
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ## 1.Seprate the NULL values

# %%
missing_value_per = df.isnull().sum()/df.shape[0] * 100
missing_value_clm_gre_20 = missing_value_per[missing_value_per > 20].keys()
df2_drop_clm.shape
# Out:
# (1460, 76)

# %%
df3_num=df2_drop_clm.select_dtypes(include=['int64','float64'])
df3_num.shape
# Out:
# (1460, 38)

# %%
# drop_col=("MasVnrArea","GarageYrBlt")
df3_num.drop(columns=["MasVnrArea","GarageYrBlt"],inplace=True)
df3_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
test_data=df3_num[df3_num["LotFrontage"].isnull()]

# %%
test_data.head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 7    8          60          NaN    10382            7            6       1973
# 12  13          20          NaN    12968            5            6       1962
# 14  15          20          NaN    10920            6            5       1960
# 16  17          20          NaN    11241            6            7       1970
# 24  25          20          NaN     8246            5            8       1968
#
#     YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 7           1973         859          32        216         1107      1107
# 12          1962         737           0        175          912       912
# 14          1960         733           0        520         1253      1253
# 16          1970         578           0        426         1004      1004
# 24          2001         188         668        204         1060      1060
#
# ...

# %% [markdown]
# ## 2.Drop the NULL values from the data frame (df3_num) and consider as train data

# %%
df3_num.dropna(inplace=True)

# %%
df3_num
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# 13      14          20         91.0    10652            7            5
# ...

# %%
df3_num.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %% [markdown]
# ## 3.create x_train & y_train from data frame df3_num

# %%
#here we take "SalePrice" as y_train data
y_train=df3_num["SalePrice"]

# %%
x_train=df3_num.drop("LotFrontage",axis=True)
x_train.shape
# Out:
# (1201, 35)

# %% [markdown]
# ## 4.Build the model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 5.Create the x_test from test_data

# %%
x_test=test_data.drop("LotFrontage",axis=1)

# %%
x_test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %% [markdown]
# ## 6.Apply the model on x_test and predicting the missing values

# %%
y_pred=lr.predict(x_test)

# %%
y_pred.shape
# Out:
# (259,)

# %% [markdown]
# ## 7.Replece the missing values with predicted values

# %%
test_data.loc[test_data.LotFrontage.isnull(),'LotFrontage'] = y_pred

# %%
test_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60     200000.0    10382            7            6
# 12      13          20     144000.0    12968            5            6
# 14      15          20     157000.0    10920            6            5
# 16      17          20     149000.0    11241            6            7
# 24      25          20     154000.0     8246            5            8
# 31      32          20     149350.0     8544            5            6
# 42      43          85     144000.0     9180            5            7
# 43      44          20     130250.0     9200            5            6
# 50      51          60     177000.0    13869            6            6
# 64      65          60     219500.0     9375            7            5
# 66      67          20     180000.0    19900            7            5
# 76      77          20     135750.0     8475            4            7
# ...

# %% [markdown]
# ## ............END............
